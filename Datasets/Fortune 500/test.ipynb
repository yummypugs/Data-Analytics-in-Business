# %%
import pandas as pd

# %%
pd.read_csv("Fortune_500_Corporate_Headquarters.csv")
# Out:
#                 X             Y  FID  OBJECTID  RANK  \
# 0   -1.293321e+07  5.403709e+06    1         1    49
# 1   -1.292942e+07  5.392879e+06    2         2   226
# 2   -8.842930e+06  4.313449e+06    3         3   290
# 3   -1.357618e+07  4.507432e+06    4         4   440
# 4   -1.357871e+07  4.508509e+06    5         5   198
# ..            ...           ...  ...       ...   ...
# 495 -9.784044e+06  5.206344e+06  496       496   111
# 496 -8.367717e+06  4.859359e+06  497       497    31
# 497 -9.407100e+06  4.736452e+06  498       498    36
# 498 -1.038271e+07  5.617628e+06  499       499   239
# 499 -1.035218e+07  5.613759e+06  500       500    94
#
#                             NAME                         ADDRESS  \
# 0                ALBERTSONS COS.        250 PARKCENTER BOULEVARD
# 1              MICRON TECHNOLOGY          8000 SOUTH FEDERAL WAY
# 2    LABORATORY CORP. OF AMERICA           358 SOUTH MAIN STREET
# ...

# %%
pd.read_csv("Fortune_1000.csv")
# Out:
#                      company  rank  rank_change  revenue  profit  \
# 0                      Jabil   104         17.0  27266.4    53.9
# 1     Mondelez International   108          9.0  26581.0  3555.0
# 2           Paramount Global   109          2.0  26186.0  2422.0
# 3                    Netflix   115         49.0  24996.1  2761.4
# 4                  Starbucks   125        -11.0  23518.0   928.3
# ..                       ...   ...          ...      ...     ...
# 995                 Michaels   506          0.0   5271.1   294.9
# 996  Alexion Pharmaceuticals   459          0.0   6069.9   603.4
# 997   Navistar International   389       -105.0   7503.0  -347.0
# 998          Magellan Health   390         42.0   7501.5   382.3
# 999        Core-Mark Holding   224         16.0  13617.1    63.2
#
#      num. of employees                         sector            city state  \
# 0                  NaN                     Technology  St. Petersburg    FL
# ...
