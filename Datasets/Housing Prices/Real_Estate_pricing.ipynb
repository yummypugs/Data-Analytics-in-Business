# %%
import pandas as pd
df = pd.read_csv("All Homes Seasonally adjusted.csv")
df
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     county        CA    CA
# 1          139         1         Cook County     county        IL    IL
# 2         1090         2       Harris County     county        TX    TX
# 3         2402         3     Maricopa County     county        AZ    AZ
# 4         2841         4    San Diego County     county        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 2832       828      3104       Alpine County     county        CA    CA
# 2833      2345      3113     Hinsdale County     county        CO    CO
# 2834      1933      3114      Mineral County     county        CO    CO
# 2835      1648      3129      Daggett County     county        UT    UT
# 2836      2518      3132     San Juan County     county        CO    CO
#
#                                      Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# ...

# %%
df = pd.read_csv("mid tier metro.csv")
df.sort_values("SizeRank")
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     1996-01-31  \
# 0      102001         0    United States    country       NaN  108664.065693
# 1      394913         1     New York, NY        msa        NY  188522.820365
# 2      753899         2  Los Angeles, CA        msa        CA  186551.889182
# 3      394463         3      Chicago, IL        msa        IL  147298.360904
# 4      394514         4       Dallas, TX        msa        TX  113332.216364
# ..        ...       ...              ...        ...       ...            ...
# 894    753929       923       Zapata, TX        msa        TX            NaN
# 895    394743       924    Ketchikan, AK        msa        AK            NaN
# 896    753874       925        Craig, CO        msa        CO   66456.052724
# 897    394767       926       Lamesa, TX        msa        TX            NaN
# 898    395188       927       Vernon, TX        msa        TX            NaN
#
# ...

# %%
df = pd.read_csv("All Homes Metro.csv")
df.StateName.value_counts()
# Out:
# TX    67
# OH    46
# GA    37
# IN    36
# NC    36
# CA    34
# PA    34
# MI    31
# FL    29
# NY    26
# IL    26
# TN    26
# MO    25
# WI    23
# OK    21
# MN    21
# AR    20
# AL    20
# OR    20
# KY    20
# WA    20
# IA    19
# KS    19
# MS    17
# LA    17
# CO    17
# NM    16
# SC    15
# VA    14
# ID    13
# NE    12
# AZ    11
# SD    10
# NV     9
# WY     9
# UT     8
# WV     8
# ND     7
# MT     7
# MA     6
# MD     6
# NH     6
# CT     5
# HI     4
# ME     4
# AK     4
# NJ     4
# VT     4
# DE     2
# RI     1
# Name: StateName, dtype: int64
