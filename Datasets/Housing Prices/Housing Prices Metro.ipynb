# %%
import pandas as pd
All = pd.read_csv("Metro Datasets/All Homes Metro.csv")
All
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2000-01-31  \
# 0      102001         0    United States    country       NaN    127881.0
# 1      394913         1     New York, NY        msa        NY    224676.0
# 2      753899         2  Los Angeles, CA        msa        CA    227786.0
# 3      394463         3      Chicago, IL        msa        IL    170004.0
# 4      394514         4       Dallas, TX        msa        TX    129921.0
# ..        ...       ...              ...        ...       ...         ...
# 888    753929       923       Zapata, TX        msa        TX         NaN
# 889    394743       924    Ketchikan, AK        msa        AK         NaN
# 890    753874       925        Craig, CO        msa        CO     94670.0
# 891    394767       926       Lamesa, TX        msa        TX         NaN
# 892    395188       927       Vernon, TX        msa        TX         NaN
#
#      2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2021-11-30  \
# ...

# %%
All.value_counts("StateName")
# Out:
# StateName
# TX    67
# OH    46
# GA    37
# IN    36
# NC    36
# CA    34
# PA    34
# MI    31
# FL    29
# NY    26
# IL    26
# TN    26
# MO    25
# WI    23
# OK    21
# MN    21
# WA    20
# KY    20
# AL    20
# AR    20
# OR    20
# IA    19
# KS    19
# LA    17
# CO    17
# MS    17
# NM    16
# SC    15
# VA    14
# ID    13
# NE    12
# AZ    11
# SD    10
# NV     9
# WY     9
# UT     8
# WV     8
# MT     7
# ND     7
# NH     6
# MD     6
# MA     6
# CT     5
# NJ     4
# ME     4
# VT     4
# HI     4
# AK     4
# DE     2
# RI     1
# dtype: int64

# %%
df = pd.read_csv("Metro Datasets/Bottom Tier Metro.csv")
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2000-01-31  \
# 0      102001         0    United States    country       NaN     65768.0
# 1      394913         1     New York, NY        msa        NY    140047.0
# 2      753899         2  Los Angeles, CA        msa        CA    148997.0
# 3      394463         3      Chicago, IL        msa        IL    106362.0
# 4      394514         4       Dallas, TX        msa        TX     82538.0
# ..        ...       ...              ...        ...       ...         ...
# 888    753929       923       Zapata, TX        msa        TX         NaN
# 889    394743       924    Ketchikan, AK        msa        AK         NaN
# 890    753874       925        Craig, CO        msa        CO     59870.0
# 891    394767       926       Lamesa, TX        msa        TX         NaN
# 892    395188       927       Vernon, TX        msa        TX         NaN
#
#      2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2021-11-30  \
# ...

# %%
df = pd.read_csv("Metro Datasets/Mid Tier Metro.csv")
#df.StateName.value_counts()
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     1996-01-31  \
# 0      102001         0    United States    country       NaN  108664.065693
# 1      394913         1     New York, NY        msa        NY  188522.820365
# 2      753899         2  Los Angeles, CA        msa        CA  186551.889182
# 3      394463         3      Chicago, IL        msa        IL  147298.360904
# 4      394514         4       Dallas, TX        msa        TX  113332.216364
# ..        ...       ...              ...        ...       ...            ...
# 894    753929       923       Zapata, TX        msa        TX            NaN
# 895    394743       924    Ketchikan, AK        msa        AK            NaN
# 896    753874       925        Craig, CO        msa        CO   66456.052724
# 897    394767       926       Lamesa, TX        msa        TX            NaN
# 898    395188       927       Vernon, TX        msa        TX            NaN
#
# ...

# %%
df = pd.read_csv("Metro Datasets/Top Tier Metro.csv")
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2000-01-31  \
# 0      102001         0    United States    country       NaN    242875.0
# 1      394913         1     New York, NY        msa        NY    398618.0
# 2      753899         2  Los Angeles, CA        msa        CA    412833.0
# 3      394463         3      Chicago, IL        msa        IL    295109.0
# 4      394514         4       Dallas, TX        msa        TX    231125.0
# ..        ...       ...              ...        ...       ...         ...
# 888    753929       923       Zapata, TX        msa        TX         NaN
# 889    394743       924    Ketchikan, AK        msa        AK         NaN
# 890    753874       925        Craig, CO        msa        CO    158031.0
# 891    394767       926       Lamesa, TX        msa        TX         NaN
# 892    395188       927       Vernon, TX        msa        TX         NaN
#
#      2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2021-11-30  \
# ...
