# %%
import pandas as pd

# %%
companies = pd.read_csv("../../Datasets/Fortune 500/Fortune_500_Corporate_Headquarters_arcgis.csv")
#companies.head()
counties = pd.read_csv("../../Datasets/Housing Prices/County Datasets/All Homes County.csv")
ohcounties = counties[counties["State"] == "OH"]
ohcounties = ohcounties.rename(columns={"RegionName":"index"})
ohcounties = ohcounties.set_index("index")
ohcounties = ohcounties.drop(ohcounties.loc[:, "RegionID":"SizeRank"], axis=1)
ohcounties = ohcounties.drop(ohcounties.loc[:, "RegionType":"MunicipalCodeFIPS"], axis=1)
ohcounties # should be 88
# Out:
#                    2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# index
# Franklin County      124134.0    124275.0    124536.0    124977.0    125448.0
# Cuyahoga County      120292.0    120632.0    120904.0    121418.0    122281.0
# Hamilton County      124526.0    124164.0    123721.0    124156.0    124923.0
# Summit County        114400.0    114723.0    114868.0    115272.0    115520.0
# Montgomery County    100142.0     99323.0     99446.0     99366.0     99933.0
# ...                       ...         ...         ...         ...         ...
# Harrison County       57924.0     58183.0     58153.0     58606.0     58913.0
# Morgan County             NaN         NaN         NaN         NaN         NaN
# Noble County              NaN         NaN         NaN         NaN         NaN
# Monroe County             NaN         NaN         NaN         NaN         NaN
# Vinton County             NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
ohcounties = ohcounties.transpose()
ohcounties = ohcounties.reset_index()
ohcounties = ohcounties.rename(columns={"index": "Date"})
#ohcounties.to_excel("Ohio counties dataset.xlsx")
ohcounties
# Out:
# index        Date  Franklin County  Cuyahoga County  Hamilton County  \
# 0      2000-01-31         124134.0         120292.0         124526.0
# 1      2000-02-29         124275.0         120632.0         124164.0
# 2      2000-03-31         124536.0         120904.0         123721.0
# 3      2000-04-30         124977.0         121418.0         124156.0
# 4      2000-05-31         125448.0         122281.0         124923.0
# ..            ...              ...              ...              ...
# 267    2022-04-30         275481.0         194720.0         236987.0
# 268    2022-05-31         278800.0         196968.0         239982.0
# 269    2022-06-30         281801.0         198809.0         241494.0
# 270    2022-07-31         284115.0         199227.0         240672.0
# 271    2022-08-31         286187.0         199777.0         239838.0
#
# index  Summit County  Montgomery County  Lucas County  Butler County  \
# ...

# %%
ohcounties = pd.read_excel("Ohio counties dataset.xlsx")
ohcounties
# Out:
#      Unnamed: 0        Date  Franklin  Cuyahoga  Hamilton    Summit  \
# 0             0  2000-01-31    124134    120292  124526.0  114400.0
# 1             1  2000-02-29    124275    120632  124164.0  114723.0
# 2             2  2000-03-31    124536    120904  123721.0  114868.0
# 3             3  2000-04-30    124977    121418  124156.0  115272.0
# 4             4  2000-05-31    125448    122281  124923.0  115520.0
# ..          ...         ...       ...       ...       ...       ...
# 267         267  2022-04-30    275481    194720  236987.0  193401.0
# 268         268  2022-05-31    278800    196968  239982.0  196284.0
# 269         269  2022-06-30    281801    198809  241494.0  198679.0
# 270         270  2022-07-31    284115    199227  240672.0  200207.0
# 271         271  2022-08-31    286187    199777  239838.0  200731.0
#
#      Montgomery     Lucas  Butler   Stark  ...   Carroll     Henry     Meigs  \
# ...
