# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from statsmodels.api import OLS
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import MultipleLocator

# %%
training_data = pd.read_csv("house-prices-advanced-regression-techniques/train.csv", index_col="Id")

column_to_remove = list(training_data.select_dtypes(include=['category','object'])) 
training_data = training_data.drop(column_to_remove, axis=1)
training_data
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# Id                                                      ...
# 1             2003       196.0         706           0  ...           0
# 2             1976         0.0         978           0  ...         298
# 3             2002       162.0         486           0  ...           0
# 4             1970         0.0         216           0  ...           0
# 5             2000       350.0         655           0  ...         192
# ...            ...         ...         ...         ...  ...         ...
# 1456          2000         0.0           0           0  ...           0
# 1457          1988       119.0         790         163  ...         349
# 1458          2006         0.0         275           0  ...           0
# 1459          1996         0.0          49        1029  ...         366
# 1460          1965         0.0         830         290  ...         736
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# Id
# 1              61              0          0            0         0        0
# 2               0              0          0            0         0        0
# 3              42              0          0            0         0        0
# 4              35            272          0            0         0        0
# 5              84              0          0            0         0        0
# ...           ...            ...        ...          ...       ...      ...
# 1456           40              0          0            0         0        0
# 1457            0              0          0            0         0        0
# 1458           60              0          0            0         0     2500
# 1459            0            112          0            0         0        0
# 1460           68              0          0            0         0        0
#
#       MoSold  YrSold  SalePrice
# Id
# 1          2    2008     208500
# 2          5    2007     181500
# 3          9    2008     223500
# 4          2    2006     140000
# 5         12    2008     250000
# ...      ...     ...        ...
# 1456       8    2007     175000
# 1457       2    2010     210000
# 1458       5    2010     266500
# 1459       4    2010     142125
# 1460       6    2008     147500
#
# [1460 rows x 37 columns]

# %%
training_data.loc[training_data['LotFrontage'].isna() , 'LotFrontage'] = 0
training_data.loc[training_data['GarageYrBlt'].isna() , 'GarageYrBlt'] = 0
training_data.loc[training_data['MasVnrArea'].isna() , 'MasVnrArea'] = 0

training_data
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# Id                                                      ...
# 1             2003       196.0         706           0  ...           0
# 2             1976         0.0         978           0  ...         298
# 3             2002       162.0         486           0  ...           0
# 4             1970         0.0         216           0  ...           0
# 5             2000       350.0         655           0  ...         192
# ...            ...         ...         ...         ...  ...         ...
# 1456          2000         0.0           0           0  ...           0
# 1457          1988       119.0         790         163  ...         349
# 1458          2006         0.0         275           0  ...           0
# 1459          1996         0.0          49        1029  ...         366
# 1460          1965         0.0         830         290  ...         736
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# Id
# 1              61              0          0            0         0        0
# 2               0              0          0            0         0        0
# 3              42              0          0            0         0        0
# 4              35            272          0            0         0        0
# 5              84              0          0            0         0        0
# ...           ...            ...        ...          ...       ...      ...
# 1456           40              0          0            0         0        0
# 1457            0              0          0            0         0        0
# 1458           60              0          0            0         0     2500
# 1459            0            112          0            0         0        0
# 1460           68              0          0            0         0        0
#
#       MoSold  YrSold  SalePrice
# Id
# 1          2    2008     208500
# 2          5    2007     181500
# 3          9    2008     223500
# 4          2    2006     140000
# 5         12    2008     250000
# ...      ...     ...        ...
# 1456       8    2007     175000
# 1457       2    2010     210000
# 1458       5    2010     266500
# 1459       4    2010     142125
# 1460       6    2008     147500
#
# [1460 rows x 37 columns]

# %%
columns_has_null = training_data.isna().sum().sort_values(ascending=False)
columns_has_null[columns_has_null > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Testing training data on the training dataset with a 0.75 to 0.25 ratio training data - testing data

# %%
X = training_data.iloc[:, :-1]
y = training_data.iloc[:, -1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, train_size=0.75)

# %%
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# C:\Users\ianpe\AppData\Local\Temp\ipykernel_4452\3799881120.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train, y_train)
# RandomForestRegressor()

# %%
print("model score on training data:", forest.score(X_train, y_train))
# Out:
# model score on training data: 0.9746114614158132

# %%
print("model score on test data:", forest.score(X_test, y_test))
# Out:
# model score on test data: 0.8930809428408597

# %% [markdown]
# # Matrix

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(training_data.corr().abs(),  annot=True)
# Out:
# <AxesSubplot:>

# %%
matrix = training_data.corr().abs()
columns_to_keep = matrix.iloc[-1, :]>=0.15
rows_to_keep = matrix.iloc[:, -1]>=0.15
new_matrix = matrix.loc[rows_to_keep, columns_to_keep]
new_matrix
# Out:
#               LotFrontage   LotArea  OverallQual  YearBuilt  YearRemodAdd  \
# LotFrontage      1.000000  0.100739     0.176561   0.036853      0.078686
# LotArea          0.100739  1.000000     0.105806   0.014228      0.013788
# OverallQual      0.176561  0.105806     1.000000   0.572323      0.550684
# YearBuilt        0.036853  0.014228     0.572323   1.000000      0.592855
# YearRemodAdd     0.078686  0.013788     0.550684   0.592855      1.000000
# MasVnrArea       0.105010  0.103321     0.407252   0.311600      0.176529
# BsmtFinSF1       0.076670  0.214103     0.239666   0.249503      0.128451
# BsmtUnfSF        0.160829  0.002618     0.308159   0.149040      0.181133
# TotalBsmtSF      0.238274  0.260833     0.537808   0.391452      0.291066
# 1stFlrSF         0.245181  0.299475     0.476224   0.281986      0.240379
# 2ndFlrSF         0.042549  0.050986     0.295493   0.010308      0.140024
# GrLivArea        0.220347  0.263116     0.593007   0.199010      0.287389
# BsmtFullBath     0.010514  0.158155     0.111098   0.187599      0.119470
# FullBath         0.120548  0.126031     0.550600   0.468271      0.439046
# HalfBath         0.012952  0.014259     0.273458   0.242656      0.183331
# BedroomAbvGr     0.144494  0.119690     0.101676   0.070651      0.040581
# TotRmsAbvGrd     0.221396  0.190015     0.427452   0.095589      0.191740
# Fireplaces       0.044018  0.271364     0.396765   0.147716      0.112581
# GarageYrBlt      0.019317  0.072599     0.288998   0.272029      0.146357
# GarageCars       0.165229  0.154871     0.600671   0.537850      0.420622
# GarageArea       0.201473  0.180403     0.562022   0.478954      0.371600
# WoodDeckSF       0.016780  0.171698     0.238923   0.224880      0.205726
# OpenPorchSF      0.069605  0.084774     0.308819   0.188686      0.226298
# SalePrice        0.209624  0.263843     0.790982   0.522897      0.507101
#
#               MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  ...  \
# LotFrontage     0.105010    0.076670   0.160829     0.238274  0.245181  ...
# LotArea         0.103321    0.214103   0.002618     0.260833  0.299475  ...
# OverallQual     0.407252    0.239666   0.308159     0.537808  0.476224  ...
# YearBuilt       0.311600    0.249503   0.149040     0.391452  0.281986  ...
# YearRemodAdd    0.176529    0.128451   0.181133     0.291066  0.240379  ...
# MasVnrArea      1.000000    0.261256   0.113862     0.360067  0.339850  ...
# BsmtFinSF1      0.261256    1.000000   0.495251     0.522396  0.445863  ...
# BsmtUnfSF       0.113862    0.495251   1.000000     0.415360  0.317987  ...
# TotalBsmtSF     0.360067    0.522396   0.415360     1.000000  0.819530  ...
# 1stFlrSF        0.339850    0.445863   0.317987     0.819530  1.000000  ...
# 2ndFlrSF        0.173800    0.137079   0.004469     0.174512  0.202646  ...
# GrLivArea       0.388052    0.208171   0.240257     0.454868  0.566024  ...
# BsmtFullBath    0.083010    0.649212   0.422900     0.307351  0.244671  ...
# FullBath        0.272999    0.058543   0.288886     0.323722  0.380637  ...
# HalfBath        0.199108    0.004262   0.041118     0.048804  0.119916  ...
# BedroomAbvGr    0.102775    0.107355   0.166643     0.050450  0.127401  ...
# TotRmsAbvGrd    0.279568    0.044316   0.250647     0.285573  0.409516  ...
# Fireplaces      0.247015    0.260011   0.051575     0.339519  0.410531  ...
# GarageYrBlt     0.132696    0.115843   0.042720     0.176359  0.166642  ...
# GarageCars      0.361945    0.224054   0.214175     0.434585  0.439317  ...
# GarageArea      0.370884    0.296970   0.183303     0.486665  0.489782  ...
# WoodDeckSF      0.159991    0.204306   0.005316     0.232019  0.235459  ...
# OpenPorchSF     0.122528    0.111761   0.129005     0.247264  0.211671  ...
# SalePrice       0.472614    0.386420   0.214479     0.613581  0.605852  ...
#
#               HalfBath  BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# LotFrontage   0.012952      0.144494      0.221396    0.044018     0.019317
# LotArea       0.014259      0.119690      0.190015    0.271364     0.072599
# OverallQual   0.273458      0.101676      0.427452    0.396765     0.288998
# YearBuilt     0.242656      0.070651      0.095589    0.147716     0.272029
# YearRemodAdd  0.183331      0.040581      0.191740    0.112581     0.146357
# MasVnrArea    0.199108      0.102775      0.279568    0.247015     0.132696
# BsmtFinSF1    0.004262      0.107355      0.044316    0.260011     0.115843
# BsmtUnfSF     0.041118      0.166643      0.250647    0.051575     0.042720
# TotalBsmtSF   0.048804      0.050450      0.285573    0.339519     0.176359
# 1stFlrSF      0.119916      0.127401      0.409516    0.410531     0.166642
# 2ndFlrSF      0.609707      0.502901      0.616423    0.194561     0.064402
# GrLivArea     0.415772      0.521270      0.825489    0.461679     0.162543
# BsmtFullBath  0.030905      0.150673      0.053275    0.137928     0.049270
# FullBath      0.136381      0.363252      0.554784    0.243671     0.137464
# HalfBath      1.000000      0.226651      0.343415    0.203649     0.117166
# BedroomAbvGr  0.226651      1.000000      0.676620    0.107570     0.009850
# TotRmsAbvGrd  0.343415      0.676620      1.000000    0.326114     0.095607
# Fireplaces    0.203649      0.107570      0.326114    1.000000     0.186264
# GarageYrBlt   0.117166      0.009850      0.095607    0.186264     1.000000
# GarageCars    0.219178      0.086106      0.362289    0.300789     0.598005
# GarageArea    0.163549      0.065253      0.337822    0.269141     0.560783
# WoodDeckSF    0.108080      0.046854      0.165984    0.200019     0.117305
# OpenPorchSF   0.199740      0.093810      0.234192    0.169405     0.049877
# SalePrice     0.284108      0.168213      0.533723    0.466929     0.261366
#
#               GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  SalePrice
# LotFrontage     0.165229    0.201473    0.016780     0.069605   0.209624
# LotArea         0.154871    0.180403    0.171698     0.084774   0.263843
# OverallQual     0.600671    0.562022    0.238923     0.308819   0.790982
# YearBuilt       0.537850    0.478954    0.224880     0.188686   0.522897
# YearRemodAdd    0.420622    0.371600    0.205726     0.226298   0.507101
# MasVnrArea      0.361945    0.370884    0.159991     0.122528   0.472614
# BsmtFinSF1      0.224054    0.296970    0.204306     0.111761   0.386420
# BsmtUnfSF       0.214175    0.183303    0.005316     0.129005   0.214479
# TotalBsmtSF     0.434585    0.486665    0.232019     0.247264   0.613581
# 1stFlrSF        0.439317    0.489782    0.235459     0.211671   0.605852
# 2ndFlrSF        0.183926    0.138347    0.092165     0.208026   0.319334
# GrLivArea       0.467247    0.468997    0.247433     0.330224   0.708624
# BsmtFullBath    0.131881    0.179189    0.175315     0.067341   0.227122
# FullBath        0.469672    0.405656    0.187703     0.259977   0.560664
# HalfBath        0.219178    0.163549    0.108080     0.199740   0.284108
# BedroomAbvGr    0.086106    0.065253    0.046854     0.093810   0.168213
# TotRmsAbvGrd    0.362289    0.337822    0.165984     0.234192   0.533723
# Fireplaces      0.300789    0.269141    0.200019     0.169405   0.466929
# GarageYrBlt     0.598005    0.560783    0.117305     0.049877   0.261366
# GarageCars      1.000000    0.882475    0.226342     0.213569   0.640409
# GarageArea      0.882475    1.000000    0.224666     0.241435   0.623431
# WoodDeckSF      0.226342    0.224666    1.000000     0.058661   0.324413
# OpenPorchSF     0.213569    0.241435    0.058661     1.000000   0.315856
# SalePrice       0.640409    0.623431    0.324413     0.315856   1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(new_matrix,  annot=True)
# Out:
# <AxesSubplot:>
